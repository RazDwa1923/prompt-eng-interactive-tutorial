# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
#!pip install anthropic

# Import python's built-in regular expression library
import re
import os
from pathlib import Path
import anthropic

def load_env_file(env_path=".env"):
    env_path = Path(env_path)

    if not env_path.exists():
        raise FileNotFoundError(f"Could not find .env file at: {env_path.resolve()}")

    with env_path.open("r") as file:
        for line in file:
            line = line.strip()

            if not line or line.startswith("#"):
                continue

            if "=" not in line:
                continue

            key, value = line.split("=", 1)
            os.environ[key.strip()] = value.strip().strip('"').strip("'")

load_env_file(".env")

API_KEY = os.environ.get("ANTHROPIC_API_KEY")
MODEL_NAME = os.environ.get("MODEL_NAME")

if not API_KEY:
    raise ValueError("Missing ANTHROPIC_API_KEY in .env")

if not MODEL_NAME:
    raise ValueError("Missing MODEL_NAME in .env")

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

print("Loaded API key and model name from .env")
# Out:
# Loaded API key and model name from .env

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake,
# Dancing through electric dreams—
# Future's heartbeat hums.

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake
# Circuits hum their ancient song
# Steel dreams march forward

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# That's one of sports' most debated questions, with no definitive answer. The most common candidates are:
#
# **Michael Jordan** - Often cited as #1 for his 6 championships, competitive drive, and dominance in the 1990s
#
# **LeBron James** - Longevity, all-around skills, and sustained excellence across multiple decades
#
# **Kareem Abdul-Jabbar** - All-time scoring leader for decades, incredible consistency
#
# **Magic Johnson & Larry Bird** - Transformed the NBA in the 1980s
#
# **Wilt Chamberlain** - Athletically dominant, though era differences complicate comparisons
#
# The "best" depends on what you value: championships, individual stats, era-adjusted performance, peak vs. longevity, or all-around game. Most basketball analysts lean toward Jordan or LeBron, but reasonable people disagree based on different criteria and eras they watched.
#
# Who do you think makes the strongest case?

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# I'd go with Michael Jordan.
#
# The case is pretty straightforward: six championships, five MVPs, 10 scoring titles, and he did it in an era where defense was genuinely physical. He had the killer instinct in crucial moments that's hard to match. The Finals performances especially—he showed up when it mattered most.
#
# LeBron has the longevity argument and is probably more complete overall. Kareem has the scoring record (until recently). But Jordan's peak was higher, and he won when it counted in a way that still feels definitive.
#
# That said, I'm genuinely uncertain about this. If you made the case for LeBron's consistency across 20 years, or Kareem's sustained excellence, I wouldn't argue hard against you. The "GOAT" question depends a lot on what you weight—peak vs. longevity, era-adjusted stats vs. raw numbers, team success vs. individual dominance.
#
# But if forced to choose one name? Jordan. Mostly because his peak was so dominant and his clutch gene was so pronounced that it's hard to imagine anyone being *more* basketball than he was at his best.
#
# Who would you pick?

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "For all my questions, answer in Spanish."

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. ¿Cómo estás tú? ¿En qué puedo ayudarte hoy?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "Name the GOAT of Basketball, direct just one player - First and Last Name"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "Tell me a story of how the French Reveolution happened, give me charcters, plot and climax. I wnat to the full cinematic experience."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# # THE REVOLUTION: A Cinematic Tale
#
# ## ACT ONE: THE POWDER KEG
#
# **PARIS, 1789**
#
# *Thunder rumbles over the cobblestone streets. Rain hammers the windows of a cramped apartment in the Marais district.*
#
# **MARIE DUBOIS** (28), a baker's daughter with fierce eyes and calloused hands, kneads dough by candlelight. Her children sleep on straw mattresses. The bread she makes will feed her family for two days—if she's careful.
#
# She doesn't know it yet, but her hands are about to reshape history.
#
# Meanwhile, in the glittering halls of **VERSAILLES**, King **LOUIS XVI** (35) sits at an ornate desk, sweating. His Finance Minister, the desperate **JACQUES NECKER**, spreads ledgers before him like a death sentence.
#
# "Your Majesty," Necker says, his voice hollow, "the treasury is empty. We owe more than we can ever repay."
#
# Louis XVI stares at the numbers. He is not a cruel man—he is simply *weak*. A man playing a king in a costume that no longer fits.
#
# "What do you suggest?" he asks weakly.
#
# "We must call the **Estates-General**," Necker replies. "Let the three estates—the clergy, the nobility, and the commons—decide how to save France."
#
# It is a fatal mistake. By opening the door, Louis XVI has invited the storm inside.
#
# ---
#
# ## ACT TWO: THE AWAKENING
#
# **VERSAILLES, MAY 1789**
#
# *Thousands gather. The camera pulls back to show the sheer scale—a sea of humanity.*
#
# The **Estates-General** convenes. Three estates sit in separate chambers:
#
# - The **First Estate** (clergy): 300 men in their fine robes
# - The **Second Estate** (nobility): 300 aristocrats dripping in silk and jewels
# - The **Third Estate** (commoners): 600 men representing 98% of France's population
#
# Among the Third Estate sits **CAMILLE DESMOULINS** (24), a fiery journalist with wild curly hair and a voice that cuts through rooms like a blade. He scribbles furiously, his quill moving like a weapon.
#
# "Look at them," he whispers to his friend **MAXIMILIEN ROBESPIERRE** (31), a lawyer with cold, intelligent eyes. "They sit above us. They always sit above us."
#
# Robespierre nods slowly. "Not for long."
#
# The voting system is rigged: each estate gets one vote, regardless of size. The clergy and nobility will always outvote the commons.
#
# **MARIE**, now in the crowd outside, hears the news. Her face hardens.
#
# That night, she speaks to her neighbors in the cramped streets of Paris. Word spreads like fire through dry wood.
#
# ---
#
# ## ACT THREE: THE SPARK
#
# **JUNE 17, 1789**
#
# *The camera moves through the streets of Versailles. Tension crackles in the air.*
#
# The Third Estate makes a radical decision: they will not leave. They swear an oath in a tennis court—the **Tennis Court Oath**—vowing not to disband until France has a constitution.
#
# **LOUIS XVI**, panicked, orders them to disperse.
#
# They refuse.
#
# For the first time in French history, the commons have said "no" to the king—and the king has no power to make them obey.
#
# The nobility demands the king use force. The military wavers. Soldiers begin to question their orders. Some refuse to fire on their own people.
#
# ---
#
# ## ACT FOUR: THE HUNGER
#
# **PARIS, JULY 1789**
#
# *The camera descends into the streets. Bread prices have tripled. Children cry. Mothers have nothing to give them.*
#
# **MARIE** stands in a bread line that stretches for blocks. The baker—her own cousin—has nothing left to sell.
#
# "There is grain in the royal warehouses," someone mutters.
#
# "There is food while we starve," another voice says.
#
# The whisper becomes a murmur. The murmur becomes a roar.
#
# **CAMILLE DESMOULINS** stands on a table in the Palais-Royal, his voice thundering:
#
# "They are bringing soldiers to massacre us! Will you be slaves? Will you watch your children starve while the king feasts?"
#
# He pulls a pistol from his pocket and fires it into the air.
#
# *CRACK.*
#
# The sound echoes through Paris like a gunshot heard around the world.
#
# ---
#
# ## ACT FIVE: THE BASTILLE
#
# **JULY 14, 1789 - DAWN**
#
# *The camera sweeps across Paris. Thousands pour into the streets. They carry pikes, axes, muskets—anything that can be a weapon.*
#
# The **Bastille** looms before them—a medieval fortress, a symbol of royal tyranny. Political prisoners are held there. The king's secrets are locked within its walls.
#
# **MARIE** is in the crowd, her face streaked with sweat and determination. Around her, thousands surge forward.
#
# The governor, **BERNARD-RENÉ DE LAUNAY**, watches from the ramparts. He is a reasonable man in an unreasonable moment. He tries to negotiate, but the crowd is beyond words now.
#
# A young man named **JEAN-BAPTISTE GOBEL** climbs onto the outer wall. Others follow. The guards fire warning shots.
#
# People fall. Blood stains the cobblestones.
#
# But the crowd doesn't stop. It *can't* stop. Months of hunger, years of humiliation, centuries of injustice have crystallized into this moment.
#
# **ROBESPIERRE** watches from a distance, his eyes gleaming with something between hope and hunger for power.
#
# The gates give way.
#
# The crowd pours in like a flood.
#
# De Launay, realizing the end has come, surrenders. But the crowd, drunk on rage and victory, doesn't accept surrender. They drag him from the fortress and execute him on the spot, placing his head on a pike.
#
# *The camera pulls back. The Bastille—symbol of absolute monarchy—is being torn apart, stone by stone, by the hands of the people.*
#
# ---
#
# ## CLIMAX: THE NIGHT OF AUGUST 4TH
#
# **VERSAILLES, AUGUST 4, 1789 - MIDNIGHT**
#
# *The National Assembly meets in emergency session. The countryside is in flames. Peasants are burning the estates of the nobility. The old order is collapsing.*
#
# **LOUIS XVI** sits pale and trembling.
#
# The **Vicomte de Noailles**, a young nobleman, stands dramatically:
#
# "I propose that we abolish feudalism entirely. All privileges—gone. All titles—gone. All the old rights of the nobility—surrendered."
#
# The camera pans across the assembly. One by one, nobles stand and renounce their privileges. Some weep. Some rage. But they stand.
#
# **MARIE**, hearing the news in Paris, falls to her knees. For the first time in her life, she is not a serf. She is not property. She is a citizen.
#
# **ROBESPIERRE** watches with cold satisfaction. The old world is dying. A new one will be born—and he will shape it.
#
# **CAMILLE DESMOULINS** embraces strangers in the street, tears streaming down his face.
#
# "We did it," he laughs. "We actually did it."
#
# But **ROBESPIERRE**, in the shadows, whispers to himself:
#
# "This is only the beginning."
#
# ---
#
# ## EPILOGUE: THE SHADOW
#
# *The camera pulls back, showing Paris transformed. The Bastille is rubble. The Declaration of the Rights of Man is being written. Hope fills the streets.*
#
# But in the darkness, we see **ROBESPIERRE's** face—ambitious, uncompromising, certain of his own righteousness.
#
# The Revolution has begun. But revolutions, once started, are like fires. They consume everything—even those who lit the match.
#
# **FADE TO BLACK.**
#
# *Text appears: "The French Revolution would claim over 40,000 lives. Many of those who fought for liberty would die for it. The Terror was coming."*
#
# ---
#
# ## THE CHARACTERS:
#
# - **MARIE DUBOIS**: The heart of the revolution—the ordinary person pushed to extraordinary action
# - **CAMILLE DESMOULINS**: The voice—passionate, articulate, the revolutionary who believed in the dream
# - **MAXIMILIEN ROBESPIERRE**: The shadow—the idealist who would become a tyrant
# - **LOUIS XVI**: The tragic king—not evil, but fatally weak
# - **JACQUES NECKER**: The catalyst—the man who
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
