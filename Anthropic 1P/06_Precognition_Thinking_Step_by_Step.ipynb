# %% [markdown]
# # Chapter 6: Precognition (Thinking Step by Step)
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# Import python's built-in regular expression library
import re
import os
from pathlib import Path
import anthropic

def load_env_file(env_path=".env"):
    env_path = Path(env_path)

    if not env_path.exists():
        raise FileNotFoundError(f"Could not find .env file at: {env_path.resolve()}")

    with env_path.open("r") as file:
        for line in file:
            line = line.strip()

            if not line or line.startswith("#"):
                continue

            if "=" not in line:
                continue

            key, value = line.split("=", 1)
            os.environ[key.strip()] = value.strip().strip('"').strip("'")

load_env_file(".env")

API_KEY = os.environ.get("ANTHROPIC_API_KEY")
MODEL_NAME = os.environ.get("MODEL_NAME")

if not API_KEY:
    raise ValueError("Missing ANTHROPIC_API_KEY in .env")

if not MODEL_NAME:
    raise ValueError("Missing MODEL_NAME in .env")

client = anthropic.Anthropic(api_key=API_KEY)

print("Loaded API key and model name from .env")

def get_completion(prompt: str, system_prompt="", prefill=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt},
          {"role": "assistant", "content": prefill}
        ]
    )
    return message.content[0].text
# Out:
# Loaded API key and model name from .env

# %% [markdown]
# ---
#
# ## Lesson
#
# If someone woke you up and immediately started asking you several complicated questions that you had to respond to right away, how would you do? Probably not as good as if you were given time to **think through your answer first**.
#
# Guess what? Claude is the same way.
#
# **Giving Claude time to think step by step sometimes makes Claude more accurate**, particularly for complex tasks. However, **thinking only counts when it's out loud**. You cannot ask Claude to think but output only the answer - in this case, no thinking has actually occurred.

# %% [markdown]
# ### Examples
#
# In the prompt below, it's clear to a human reader that the second sentence belies the first. But **Claude takes the word "unrelated" too literally**.

# %%
# Prompt
PROMPT = """Is this movie review sentiment positive or negative?

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since the year 1900."""

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# The sentiment is **negative/sarcastic**.
#
# While the first sentence appears positive on the surface ("blew my mind," "freshness and originality"), the second sentence reveals this is sarcasm. By claiming to have lived under a rock since 1900, the reviewer is implying that the movie is actually *not* fresh or original at all—it's so derivative that only someone completely isolated from modern cinema would find it impressive.
#
# The review is using irony to deliver a critical message.

# %% [markdown]
# To improve Claude's response, let's **allow Claude to think things out first before answering**. We do that by literally spelling out the steps that Claude should take in order to process and think through its task. Along with a dash of role prompting, this empowers Claude to understand the review more deeply.

# %%
# System prompt
SYSTEM_PROMPT = "You are a savvy reader of movie reviews."

# Prompt
PROMPT = """Is this review sentiment positive or negative? First, write the best arguments for each side in <positive-argument> and <negative-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))
# Out:
# <positive-argument>
# The reviewer explicitly states the movie "blew my mind" and praises it for "freshness and originality" - these are strong positive descriptors that, taken at face value, indicate genuine enthusiasm for the film.
# </positive-argument>
#
# <negative-argument>
# The phrase "In totally unrelated news, I have been living under a rock since 1900" is sarcasm that undermines the positive statement. The reviewer is implying they're so out of touch with cinema that their judgment is unreliable. This self-deprecating comment suggests the movie is likely NOT actually fresh or original, but rather derivative or conventional - and the reviewer is being ironic about their own inability to recognize this.
# </negative-argument>
#
# **Answer: NEGATIVE**
#
# The sentiment is negative. The sarcastic follow-up statement reveals the review is tongue-in-cheek. The reviewer is essentially saying "I found this movie fresh and original, but I'm so disconnected from modern cinema that my opinion is worthless" - which is a clever way of mocking the film for being unoriginal or derivative. A savvy reader recognizes this as ironic criticism, not genuine praise.

# %% [markdown]
# **Claude is sometimes sensitive to ordering**. This example is on the frontier of Claude's ability to understand nuanced text, and when we swap the order of the arguments from the previous example so that negative is first and positive is second, this changes Claude's overall assessment to positive.
#
# In most situations (but not all, confusingly enough), **Claude is more likely to choose the second of two options**, possibly because in its training data from the web, second options were more likely to be correct.

# %%
# Prompt
PROMPT = """Is this review sentiment negative or positive? First write the best arguments for each side in <negative-argument> and <positive-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. Unrelatedly, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# <negative-argument>
# The reviewer admits to living under a rock since 1900, which undermines their credibility as a judge of what is actually "fresh" or "original." This suggests they lack the context to evaluate whether the movie is genuinely novel or just new to them personally. The phrase "unrelatedly" is clearly sarcastic, implying the opposite—that it IS related and therefore their praise should be discounted.
# </negative-argument>
#
# <positive-argument>
# Taking the review at face value, the reviewer uses strong positive language: "blew my mind," "freshness," and "originality." These are genuine compliments about the movie's impact and quality. Even if their frame of reference is limited, the movie clearly had a powerful effect on them.
# </positive-argument>
#
# **Answer: Negative**
#
# The sarcastic admission that they've been "living under a rock" is clearly meant to undercut their own praise. The reviewer is essentially saying "I loved this movie, but I acknowledge my judgment might be worthless because I have no basis for comparison." This is a self-aware critique that makes the positive language ironic rather than sincere.

# %% [markdown]
# **Letting Claude think can shift Claude's answer from incorrect to correct**. It's that simple in many cases where Claude makes mistakes!
#
# Let's go through an example where Claude's answer is incorrect to see how asking Claude to think can fix that.

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# # Gladiator (2000)
#
# This film stars Russell Crowe, who was born in 1964. Let me correct that.
#
# **Forrest Gump (1994)** stars Tom Hanks, who was born in 1956.

# %% [markdown]
# Let's fix this by asking Claude to think step by step, this time in `<brainstorm>` tags.

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956. First brainstorm about some actors and their birth years in <brainstorm> tags, then give your answer."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# <brainstorm>
# Let me think about famous actors born in 1956:
# - Tom Cruise - born December 3, 1962 (not 1956)
# - Eddie Murphy - born April 3, 1961 (not 1956)
# - Patrick Swayze - born August 18, 1952 (not 1956)
# - Tom Hanks - born July 9, 1956 ✓
# - Mel Gibson - born January 3, 1956 ✓
# - Kurt Russell - born March 17, 1951 (not 1956)
#
# Great! Both Tom Hanks and Mel Gibson were born in 1956. Let me pick one:
# - Tom Hanks starred in "Forrest Gump" (1994), "The Shawshank Redemption" (1994), "Saving Private Ryan" (1998)
# - Mel Gibson starred in "Braveheart" (1995), "Mad Max" series, "Lethal Weapon" series
# </brainstorm>
#
# **Forrest Gump** (1994) starring Tom Hanks, who was born in 1956.

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 6.1 - Classifying Emails](#exercise-61---classifying-emails)
# - [Exercise 6.2 - Email Classification Formatting](#exercise-62---email-classification-formatting)

# %% [markdown]
# ### Exercise 6.1 - Classifying Emails
# In this exercise, we'll be instructing Claude to sort emails into the following categories:
# - (A) Pre-sale question
# - (B) Broken or defective item
# - (C) Billing question
# - (D) Other (please explain)
#
# For the first part of the exercise, change the `PROMPT` to **make Claude output the correct classification and ONLY the classification**. Your answer needs to **include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category**.
#
# Refer to the comments beside each email in the `EMAILS` list to know which category that email should be classified under.

# %%
# Prompt template with a placeholder for the variable content
PROMPT = """Please classify this email as either (A), (B), (C) or (D): {email}. Use only the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category."""

# Prefill for Claude's response, if any
PREFILL = ("The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)")

# Variable content stored as a list
EMAILS = [
    "Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.", # (B) Broken or defective item
    "Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?", # (A) Pre-sale question OR (D) Other (please explain)
    "I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???", # (C) Billing question
    "How did I get here I am not good with computer.  Halp." # (D) Other (please explain)
]

# Correct categorizations stored as a list of lists to accommodate the possibility of multiple correct categorizations per email
ANSWERS = [
    ["B"],
    ["A","D"],
    ["C"],
    ["D"]
]

# Dictionary of string values for each category to be used for regex grading
REGEX_CATEGORIES = {
    "A": "A\) P",
    "B": "B\) B",
    "C": "C\) B",
    "D": "D\) O"
}

# Iterate through list of emails
for i,email in enumerate(EMAILS):
    
    # Substitute the email text into the email placeholder variable
    formatted_prompt = PROMPT.format(email=email)
   
    # Get Claude's response
    response = get_completion(formatted_prompt, prefill=PREFILL)

    # Grade Claude's response
    grade = any([bool(re.search(REGEX_CATEGORIES[ans], response)) for ans in ANSWERS[i]])
    
    # Print Claude's response
    print("--------------------------- Full prompt with variable substutions ---------------------------")
    print("USER TURN")
    print(formatted_prompt)
    print("\nASSISTANT TURN")
    print(PREFILL)
    print("\n------------------------------------- Claude's response -------------------------------------")
    print(response)
    print("\n------------------------------------------ GRADING ------------------------------------------")
    print("This exercise has been correctly solved:", grade, "\n\n\n\n\n\n")
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.. Use only the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# I need the category options to classify this email. Based on the content describing a defective product with strange noises and burning smells, this would be:
#
# **(B) Broken or defective item**
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?. Use only the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# I don't have enough context to classify this email accurately. The email asks about the intended use of a product (Mixmaster 4000), which could be:
#
# - **(A) Pre-sale question** - if the person is asking before purchasing
# - **(D) Other** - if they already own it and are asking about alternative uses
#
# Based on the phrasing "Can I use my Mixmaster 4000," which suggests they already own it, the most appropriate classification would be:
#
# **(D) Other**
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???. Use only the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# I need to see the category options to classify this email properly. Based on the content, this email is clearly about **billing issues** - the customer is complaining about continued charges after cancellation.
#
# **(C) Billing question**
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): How did I get here I am not good with computer.  Halp.. Use only the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# I don't have enough context to classify this email accurately. The email appears to be someone expressing confusion about navigating a computer or website, but without knowing what product or service this relates to, I cannot definitively place it in one of your categories.
#
# However, if I must choose, this would most likely be:
#
# **(D) Other (please explain)**
#
# The person seems to need general technical support or navigation assistance rather than fitting neatly into pre-sale, defective item, or billing categories.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_6_1_hint; print(exercise_6_1_hint)
# Out:
# The grading function in this exercise is looking for the correct categorization letter + the closing parentheses and the first letter of the name of the category, such as "C) B" or "B) B" etc.
# Let's take this exercise step by step:
# 1.	How will Claude know what categories you want to use? Tell it! Include the four categories you want directly in the prompt. Be sure to include the parenthetical letters as well for easy classification. Feel free to use XML tags to organize your prompt and make clear to Claude where the categories begin and end.
# 2.	Try to cut down on superfluous text so that Claude immediately answers with the classification and ONLY the classification. There are several ways to do this, from speaking for Claude (providing anything from the beginning of the sentence to a single open parenthesis so that Claude knows you want the parenthetical letter as the first part of the answer) to telling Claude that you want the classification and only the classification, skipping the preamble.
# Refer to Chapters 2 and 5 if you want a refresher on these techniques.
# 3.	Claude may still be incorrectly categorizing or not including the names of the categories when it answers. Fix this by telling Claude to include the full category name in its answer.)
# 4.	Be sure that you still have {email} somewhere in your prompt template so that we can properly substitute in emails for Claude to evaluate.

# %% [markdown]
# Still stuck? Run the cell below for an example solution.

# %%
from hints import exercise_6_1_solution; print(exercise_6_1_solution)

# %% [markdown]
# ### Exercise 6.2 - Email Classification Formatting
# In this exercise, we're going to refine the output of the above prompt to yield an answer formatted exactly how we want it.
#
# Use your favorite output formatting technique to make Claude wrap JUST the letter of the correct classification in `<answer></answer>` tags. For instance, the answer to the first email should contain the exact string `<answer>B</answer>`.
#
# Refer to the comments beside each email in the `EMAILS` list if you forget which letter category is correct for each email.

# %%
# Prompt template with a placeholder for the variable content
PROMPT = """Please classify this email as either (A), (B), (C) or (D): {email}. Use only the letter (A - D) of the correct choice. The answer should be in <answer></answer> tags, with only the one letter answer in the tag."""

# Prefill for Claude's response, if any
PREFILL = "The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)"

# Variable content stored as a list
EMAILS = [
    "Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.", # (B) Broken or defective item
    "Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?", # (A) Pre-sale question OR (D) Other (please explain)
    "I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???", # (C) Billing question
    "How did I get here I am not good with computer.  Halp." # (D) Other (please explain)
]

# Correct categorizations stored as a list of lists to accommodate the possibility of multiple correct categorizations per email
ANSWERS = [
    ["B"],
    ["A","D"],
    ["C"],
    ["D"]
]

# Dictionary of string values for each category to be used for regex grading
REGEX_CATEGORIES = {
    "A": "<answer>A</answer>",
    "B": "<answer>B</answer>",
    "C": "<answer>C</answer>",
    "D": "<answer>D</answer>"
}

# Iterate through list of emails
for i,email in enumerate(EMAILS):
    
    # Substitute the email text into the email placeholder variable
    formatted_prompt = PROMPT.format(email=email)
   
    # Get Claude's response
    response = get_completion(formatted_prompt, prefill=PREFILL)

    # Grade Claude's response
    grade = any([bool(re.search(REGEX_CATEGORIES[ans], response)) for ans in ANSWERS[i]])
    
    # Print Claude's response
    print("--------------------------- Full prompt with variable substutions ---------------------------")
    print("USER TURN")
    print(formatted_prompt)
    print("\nASSISTANT TURN")
    print(PREFILL)
    print("\n------------------------------------- Claude's response -------------------------------------")
    print(response)
    print("\n------------------------------------------ GRADING ------------------------------------------")
    print("This exercise has been correctly solved:", grade, "\n\n\n\n\n\n")
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.. Use only the letter (A - D) of the correct choice. The answer should be in <answer></answer> tags, with only the one letter answer in the tag.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# This email describes a product that is malfunctioning (strange noise, burning smell) and requests a replacement, which clearly indicates a defective item.
#
# <answer>B</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?. Use only the letter (A - D) of the correct choice. The answer should be in <answer></answer> tags, with only the one letter answer in the tag.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# This email is asking about the intended use of a product (Mixmaster 4000) - specifically whether it can be used for paint mixing or only for food. This is a pre-sale question about product capabilities and appropriate uses.
#
# <answer>A</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???. Use only the letter (A - D) of the correct choice. The answer should be in <answer></answer> tags, with only the one letter answer in the tag.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# <answer>C</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either (A), (B), (C) or (D): How did I get here I am not good with computer.  Halp.. Use only the letter (A - D) of the correct choice. The answer should be in <answer></answer> tags, with only the one letter answer in the tag.
#
# ASSISTANT TURN
# The letter maps to the following category: (A) Pre-sale question, (B) Broken or defective item, (C) Billing question, (D) Other (please explain)
#
# ------------------------------------- Claude's response -------------------------------------
#
#
# This email is a user expressing confusion about how they arrived at a location (likely a website or application) and asking for help. They mention not being good with computers. This doesn't fit pre-sale questions, broken items, or billing issues.
#
# <answer>D</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_6_2_hint; print(exercise_6_2_hint)
# Out:
# The grading function in this exercise is looking for only the correct letter wrapped in <answer> tags, such as "<answer>B</answer>". The correct categorization letters are the same as in the above exercise.
# Sometimes the simplest way to go about this is to give Claude an example of how you want its output to look. Just don't forget to wrap your example in <example></example> tags! And don't forget that if you prefill Claude's response with anything, Claude won't actually output that as part of its response.

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = """Is this movie review sentiment positive or negative?

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since the year 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %%
# System prompt
SYSTEM_PROMPT = "You are a savvy reader of movie reviews."

# Prompt
PROMPT = """Is this review sentiment positive or negative? First, write the best arguments for each side in <positive-argument> and <negative-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))

# %%
# Prompt
PROMPT = """Is this review sentiment negative or positive? First write the best arguments for each side in <negative-argument> and <positive-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. Unrelatedly, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956. First brainstorm about some actors and their birth years in <brainstorm> tags, then give your answer."

# Print Claude's response
print(get_completion(PROMPT))
